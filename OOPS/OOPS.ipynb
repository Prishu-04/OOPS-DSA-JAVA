# %% [markdown]
# # JAVA

# %% [markdown]
# ### History Of JAVA

# %% [markdown]
# 1. James Gosling, Mike Sheridan, and Patrick Naughton initiated the Java language project in June 1991.
# 2. Java was called Oak as it is a symbol of strength and chosen as a national tree of many countries like U.S.A., France, Germany, Romania, etc.

# %% [markdown]
# ### Features of JAVA

# %% [markdown]
# Java Programming is claimed as:
# 1. Simple
# 2. Robust
# 3. Portable
# 4. Object-Oriented
# 5. Architectural Neurtral
# 6. High Performance
# 7. Multi- threaded
# 8. Secure
# 9. Platform Independent
# 10. Interpreted
# 11. Dynamic

# %% [markdown]
# ### Popularity of JAVA

# %% [markdown]
# 1. Java has worldwide popularity.
# 2. Parallel and distributed development.
# 3. base for Android mobile platform.
# 4. Platform Independence.
# 5. Java offers backward compatibility.
# 6. Reliability, speed and performance.

# %% [markdown]
# ### Function Oriented Programming v/s Object Oriented programming

# %% [markdown]
# ##### Function Oriented Programming

# %% [markdown]
# 1. Program are dividde small parts called functions.
# 2. Importance is not given to data but to function.
# 3. FOP follows top down approch.
# 4. Does not have any acces specifier.
# 5.
